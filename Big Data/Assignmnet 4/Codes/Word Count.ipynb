# %% [markdown]
# Importing necessary modules

# %%
import findspark
findspark.init()

# %%
import pyspark
import sys
 
from pyspark import SparkContext, SparkConf

# %% [markdown]
# Creating a spark context

# %%
sc = SparkContext("local","PySpark Word Count Exmaple")

# %% [markdown]
# Reading the inputfile and storing each word in the file as words

# %%
words = sc.textFile("F:\Docs\Big data\Assignment\Assignmnet 4\Dataset\input.txt").flatMap(lambda line: line.split(" "))

# %% [markdown]
# We are counting the occurance of each word

# %%
wordCounts = words.map(lambda word: (word, 1)).reduceByKey(lambda a,b:a +b)

# %% [markdown]
# Saving it as a text file

# %%
wordCounts.saveAsTextFile("F:\Docs\Big data\Assignment\Assignmnet 4\Dataset\output")

# %% [markdown]
# Printing the counts

# %%
print(wordCounts.collect())
# Out:
# [('This', 7), ('is', 25), ('the', 394), ('file', 5), ('GUTINDEX.2020', 2), ('', 27363), ('Updated', 1), ('to', 79), ('May', 7), ('2,', 29), ('2020', 13), ('See', 1), ('GUTINDEX.ALL', 1), ('for', 38), ('all', 3), ('Project', 11), ('Gutenberg', 10), ('eBooks.', 1), ('-=]', 1), ('INTRODUCTION', 1), ('[=-', 1), ('a', 80), ('plain', 5), ('text', 7), ('listing', 3), ('of', 487), ('eBooks', 3), ('posted', 1), ('collection', 2), ('between', 3), ('January', 2), ('1,', 13), ('and', 267), ('December', 4), ('31,', 1), ('beginning', 1), ('with', 24), ('eBook', 8), ('number', 2), ('61070.', 1), ('It', 5), ('not', 4), ('database,', 1), ('but', 3), ('it', 3), ('useful', 1), ('identifying', 1), ('so', 1), ('that', 6), ('they', 1), ('can', 6), ('be', 7), ('downloaded', 1), ('or', 18), ('read', 1), ('online.', 1), ('HOW', 2), ('TO', 3), ('GET', 1), ('EBOOKS', 2), ('FROM', 1), ('PROJECT', 1), ('GUTENBERG', 1), ('The', 269), ('easiest', 1), ('quickest', 1), ('way', 1), ('obtain', 3), ('one', 6), ('specific', 1), ('via', 1), ('our', 5), ('search', 4), ('page', 2), ('at', 28), ('https://www.gutenberg.org/catalog/world/search', 1), ('where', 1), ('you', 9), ('by', 934), ('particular', 1), ('book', 3), ('want.', 1), ('Other', 9), ('engines', 1), ('will', 3), ('provide', 1), ('more', 4), ('information', 2), ('on', 45), ('books', 2), ('same', 2), ('author', 1), ('using', 3), ('ebook', 3), ('number,', 1), ('such', 1), ('as:', 1), ('https://www.gutenberg.org/ebooks/', 1), ("author's", 1), ('name:', 1), ('https://www.gutenberg.org/browse/authors/a', 1), ('ONLINE', 1), ('DATABASE', 1), ('online', 1), ('database', 1), ('accessed', 1), ('https://www.gutenberg.org/catalog/', 1), ('DOWNLOAD', 1), ('AN', 1), ('EBOOK', 6), ('YOUR', 1), ('MOBILE', 1), ('DEVICE', 1), ('If', 6), ('your', 12), ('device', 5), ('Internet-enabled,', 2), ('just', 1), ('visit', 1), ('catalog', 2), ('download', 3), ('available', 4), ('formats', 3), ('display.', 1), ('then', 1), ('computer', 1), ('transfer', 1), ("book's", 1), ('USB', 1), ('cable', 1), ('similar', 1), ('method.', 2), ('utilizes', 1), ('different', 1), ('format', 2), ('from', 33), ('those', 1), ('have', 3), ('an', 23), ('app', 1), ('convert', 1), ("device's", 1), ('format.', 1), ('SITE', 1), ('MAP', 1), ("you're", 1), ('interested,', 1), ('here', 1), ('Site', 1), ('Map', 1), ('Gutenberg:', 1), ('https://www.gutenberg.org/', 2), ('MIRROR', 1), ('SITES', 1), ('Mirrors', 1), ('(copies)', 1), ('complete', 1), ('are', 8), ('around', 1), ('world', 2), ('select', 1), ('nearer', 1), ('location', 1), ('link', 1), ('results', 1), ('page.', 2), ('However,', 1), ('if', 2), ('access', 2), ('wide', 1), ('web', 1), ('(www)', 1), ('direct', 1), ('links', 1), ('above', 1), ('much', 1), ('simplier.', 1), ('To', 10), ('see', 3), ('mirror', 1), ('sites,', 2), ('locate', 1), ('nearest', 1), ('you,', 1), ('visit:', 1), ('https://www.gutenberg.org/MIRRORS.ALL', 1), ('Copy', 1), ('URL', 1), ('choice', 1), ('paste', 1), ('in', 121), ('new', 3), ('tab', 1), ('browser', 1), ('tap', 1), ('Enter', 1), ('key', 1), ('keyboard.', 1), ('DIRECT', 1), ('ACCESS', 1), ('directly', 1), ('directories:', 1), ('https://www.gutenberg.org/dirs/', 1), ('PLAIN', 1), ('TEXT', 1), ('Whenever', 2), ('possible,', 1), ('distributes', 2), ('version', 2), ('(.txt)', 1), ('addition', 1), ('several', 1), ('other', 5), ('choices.', 1), ('We', 1), ('stress', 1), ('inclusion', 1), ('because', 1), ('lowest', 1), ('common', 1), ('denominator', 1), ('its', 10), ('longevity.', 1), ('Since', 1), ('began,', 1), ('dozens', 1), ('widely', 1), ('used', 1), ('come', 1), ('gone,', 1), ('still', 1), ('remains.', 1), ('Text', 2), ('accessible', 1), ('computers', 1), ('insurance', 1), ('against', 3), ('future', 1), ('obsolescence.', 1), ('only', 1), ('times', 1), ('when', 2), ('without', 1), ('impossible', 1), ('impractical', 1), ('--', 1), ('example,', 1), ('videos', 1), ('MP3', 1), ('audio', 1), ('files,', 1), ('some', 2), ('mathematical', 1), ('works.', 1), ('(Please', 1), ('note', 1), ('fil ...
